-- %%
CREATE TABLE IF NOT EXISTS users (
  user_id INT,
  name STRING,
  email STRING,
  signup_date DATE
);

INSERT INTO users (user_id, name, email, signup_date)
VALUES
  (1, 'Siddhant', 'sid@example.com', '2026-01-01'),
  (2, 'Amit', 'amit@example.com', '2026-01-02'),
  (3, 'Siddhant', 'sid@example.com', '2026-01-01'),
  (4, 'Rahul', 'rahul@example.com', '2026-01-03'),
  (5, 'Amit', 'amit@example.com', '2026-01-05'),
  (6, 'Amit', 'amit@example.com', '2026-01-05'),
  (7, 'Amit', 'amit@example.com', '2026-01-05');

-- %%
-- DROP TABLE orders;

-- %%
CREATE TABLE IF NOT EXISTS employees (
  emp_id INT,
  name STRING,
  department STRING,
  salary INT
);

INSERT INTO employees (emp_id, name, department, salary)
VALUES
  (1, 'Amit', 'DE', 90000),
  (2, 'Siddhant', 'DE', 95000),
  (3, 'Rahul', 'DA', 80000),
  (4, 'Priya', 'DS', 95000),
  (5, 'Vikram', 'DE', 70000);

-- %%
CREATE TABLE IF NOT EXISTS orders (
  order_id INT,
  customer STRING,
  product STRING
);

INSERT INTO orders (order_id, customer, product)
VALUES
  (101, 'Amit', 'Laptop'),
  (102, 'Siddhant', 'Mouse'),
  (103, 'Priya', 'Mouse'),
  (104, 'Rahul', 'Keyboard'),
  (105, 'Vikram', 'Mouse'),
  (106, 'Amit', 'Laptop'),
  (107, 'Siddhant', 'Monitor'),
  (108, 'Priya', 'Mouse'),
  (109, 'Rahul', 'Mouse'),
  (110, 'Vikram', 'Laptop'),
  (111, 'Amit', 'Desk Mat'),
  (112, 'Siddhant', 'Monitor'),
  (113, 'Priya', 'Laptop');

-- %%
CREATE TABLE IF NOT EXISTS user_updates (
  user_id INT,
  name STRING,
  country STRING,
  updated_timestamp TIMESTAMP
);

INSERT INTO user_updates (user_id, name, country, updated_timestamp)
VALUES
  (1, 'Amit', 'India', '2026-05-01 10:00:00'),
  (1, 'Amit', 'India', '2026-05-02 14:30:00'),
  (1, 'Amit', 'USA', '2026-05-03 09:00:00'),
  (2, 'Priya', 'India', '2026-05-01 11:00:00'),
  (2, 'Priya', 'India', '2026-04-28 08:00:00');
